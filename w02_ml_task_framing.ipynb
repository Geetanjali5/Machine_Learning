# %% [markdown]
# <a href="https://colab.research.google.com/github/Geetanjali5/Machine_Learning/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
### Decision

# The decision is to identify which content pages should be refreshed first to improve their search performance.

### Who acts?

#The SEO manager or content editor will use the model's output to prioritize pages for updating.

### Task Type

#**Ranking**

#The model ranks content pages according to their refresh priority rather than simply predicting whether a page will decline.

### Content Action

#The output is a prioritized list of content pages that should be refreshed first so editors can focus on the highest-impact pages.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
## Target or Proxy

#The target is **is_declining_label**, which indicates whether a content item has declined.For this assignment, it is used only as a target preview. It should not be used as a feature because related columns such as **trend_pct** and **trend_direction** are derived from it.The model's objective is to rank content pages according to their likelihood of needing a refresh.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
## Success Metric

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Load the starter dataset

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
#A simple rule such as "refresh every page with low CTR" is not enough because content performance depends on many interacting factors.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
