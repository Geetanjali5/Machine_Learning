# %% [markdown]
# <a href="https://colab.research.google.com/github/Geetanjali5/Machine_Learning/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## My Lane

I chose the **Content Decline Prediction** lane.

The goal is to identify website pages that are likely to decline in search performance so they can be updated before traffic is lost.

I selected this lane because it directly supports SEO decision-making and uses the available features in the starter dataset.
"""))
# Out:
# ## My Lane
#
# I chose the **Content Decline Prediction** lane.
#
# The goal is to identify website pages that are likely to decline in search performance so they can be updated before traffic is lost.
#
# I selected this lane because it directly supports SEO decision-making and uses the available features in the starter dataset.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Research Question

### Decision
Which content pages should be refreshed first?

### Action
Prioritize pages predicted to decline and update their content.

### Cost of a Wrong Recommendation
- If a declining page is missed, valuable search traffic may be lost.
- If a healthy page is incorrectly flagged, time and effort may be wasted updating content unnecessarily.

### Why Machine Learning?
Machine learning can analyze multiple factors together and help identify pages that are likely to decline, making it easier to prioritize updates.
"""))
# Out:
# ## Research Question
#
# ### Decision
# Which content pages should be refreshed first?
#
# ### Action
# Prioritize pages predicted to decline and update their content.
#
# ### Cost of a Wrong Recommendation
# - If a declining page is missed, valuable search traffic may be lost.
# - If a healthy page is incorrectly flagged, time and effort may be wasted updating content unnecessarily.
#
# ### Why Machine Learning?
# Machine learning can analyze multiple factors together and help identify pages that are likely to decline, making it easier to prioritize updates.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
## Observations

# The dataset contains **XXXX** pages.
# The distribution of trend directions shows that there are pages with declining performance, making this a meaningful problem for machine learning.

# These observations support my choice of the Content Decline Prediction lane because they show that there is enough variation in search performance to identify pages that may need refreshing.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# Every section above is filled

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
